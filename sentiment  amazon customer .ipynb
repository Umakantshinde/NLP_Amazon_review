# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Reviews.csv")

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
data.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
data['Helpfull%']=np.where(data['HelpfulnessDenominator']>0,data['HelpfulnessNumerator']/data['HelpfulnessDenominator'],-1)

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
data['Helpfull%'].unique()
# Out:
# array([ 1.        , -1.        ,  0.8       ,  0.        ,  0.5       ,
#         0.66666667,  0.25      ,  0.89473684,  0.83333333,  0.75      ,
#         0.33333333,  0.3       ,  0.11111111,  0.42857143,  0.875     ,
#         0.85714286,  0.2       ,  0.26315789,  0.6       ,  0.71428571,
#         0.53846154,  0.57142857,  0.91489362,  0.86666667,  0.82352941,
#         0.78571429,  0.74074074,  0.4       ,  0.375     ,  0.28571429,
#         0.14285714,  0.77777778,  0.125     ,  0.9       ,  0.94117647,
#         0.92307692,  0.7       ,  0.45454545,  0.88888889,  0.83870968,
#         0.9047619 ,  0.92857143,  0.90909091,  0.91666667,  0.84615385,
#         0.10526316,  0.98214286,  0.97826087,  0.7518797 ,  0.3125    ,
#         0.1       ,  0.18518519,  0.88      ,  0.69230769,  0.625     ,
#         0.54545455,  0.41666667,  0.45833333,  0.22222222,  0.81818182,
#         0.8125    ,  0.16666667,  0.93103448,  0.88235294,  0.23529412,
# ...

# %%
data['%upvote']=pd.cut(data['Helpfull%'],bins=[-1,0,0.2,0.4,0.6,0.8,1],labels=['Empty','0-20%','20-40%','40-60%','60-80%','80-100%'])

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
data.groupby(['Score','%upvote']).agg('count')
# Out:
#                    Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# Score %upvote
# 1     Empty      8060       8060    8060         8060                  8060
#       0-20%      2338       2338    2338         2338                  2338
#       20-40%     4649       4649    4649         4649                  4649
#       40-60%     6586       6586    6586         6586                  6586
#       60-80%     5838       5838    5838         5836                  5838
#       80-100%   12531      12531   12531        12531                 12531
# 2     Empty      4234       4234    4234         4234                  4234
#       0-20%       762        762     762          762                   762
#       20-40%     1618       1618    1618         1618                  1618
#       40-60%     3051       3051    3051         3051                  3051
#       60-80%     2486       2486    2486         2486                  2486
# ...

# %%
data_s=data.groupby(['Score','%upvote']).agg({'Id':'count'}).reset_index()

# %%
data_s
# Out:
#     Score  %upvote      Id
# 0       1    Empty    8060
# 1       1    0-20%    2338
# 2       1   20-40%    4649
# 3       1   40-60%    6586
# 4       1   60-80%    5838
# 5       1  80-100%   12531
# 6       2    Empty    4234
# 7       2    0-20%     762
# 8       2   20-40%    1618
# 9       2   40-60%    3051
# 10      2   60-80%    2486
# 11      2  80-100%    7014
# 12      3    Empty    5062
# 13      3    0-20%     474
# 14      3   20-40%    1506
# 15      3   40-60%    3384
# 16      3   60-80%    2754
# 17      3  80-100%   11037
# 18      4    Empty    4780
# 19      4    0-20%     116
# 20      4   20-40%     909
# 21      4   40-60%    3185
# 22      4   60-80%    2941
# 23      4  80-100%   26707
# 24      5    Empty   11638
# 25      5    0-20%     432
# 26      5   20-40%    2275
# 27      5   40-60%   10312
# 28      5   60-80%   11060
# 29      5  80-100%  140661

# %%
pivot=data_s.pivot(index='%upvote',columns='Score')

# %%
import seaborn as sns

# %%
sns.heatmap(pivot,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:xlabel='None-Score', ylabel='%upvote'>

# %%
data['Score'].unique()
# Out:
# array([5, 1, 4, 2, 3], dtype=int64)

# %%
data1=data[data['Score']!=3]

# %%
X=data1['Text']

# %%
data1['Score'].unique()
# Out:
# array([5, 1, 4, 2], dtype=int64)

# %%
y_dict={1:0,2:0,4:1,5:1}
y=data1['Score'].map(y_dict)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c= CountVectorizer(stop_words='english')

# %%
X_c=c.fit_transform(X)

# %%
X_c.shape
# Out:
# (525814, 114969)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_c,y)

# %%
X_train.shape
# Out:
# (394360, 114969)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
ml=log.fit(X_train,y_train)
# Out:
# c:\users\utshi\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
ml.score(X_test,y_test)
# Out:
# 0.9345930895978821

# %%
w=c.get_feature_names()

# %%
coef=ml.coef_.tolist()[0]

# %%
coef_data=pd.DataFrame({'word':w,'Coefficent':coef})

# %%
coef_data
# Out:
#           word  Coefficent
# 0           00   -0.331977
# 1          000   -0.013237
# 2         0000    0.398938
# 3       000001   -0.007820
# 4        00001   -0.007675
# ...        ...         ...
# 114964  çaykur    0.000780
# 114965   çelem   -0.128632
# 114966    être    0.000000
# 114967     île    0.010814
# 114968      ît    0.000426
#
# [114969 rows x 2 columns]

# %%
coef_data=coef_data.sort_values(['Coefficent','word'],ascending=False)

# %%
coef_data.head()
# Out:
#              word  Coefficent
# 80600  pleasantly    4.278090
# 39072    downside    3.490391
# 5865    addicting    2.818967
# 87967      resist    2.754978
# 94667   skeptical    2.596722

# %%
def text_fit(X,y,nlp_model,ml_model):
    X_c=nlp_model.fit_transform(X)
    print('features:{}',format(X_c.shape[1]))
    X_train,X_test,y_train,y_test=train_test_split(X_c,y)
    ml_model.fit(X_train,y_train)
    acc=ml.score(X_test,y_test)
    print(acc)
    w=c.get_feature_names()
    coef_data=pd.DataFrame({'word':w,'Coefficent':coef})
    coef_data=coef_data.sort_values(['Coefficent','word'],ascending=False)
    print("Top 20 Positive words")
    print(coef_data.head(20))
    print("\n")
    print("Top 20 Negitive words")
    print(coef_data.tail(20))

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
c=CountVectorizer(stop_words='english')

# %%
from sklearn.linear_model import LogisticRegression

# %%
text_fit(X,y,c,LogisticRegression())
# Out:
# features:{} 114969
# c:\users\utshi\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9445585528017405
# Top 20 Positive words
#               word  Coefficent
# 80600   pleasantly    4.278090
# 39072     downside    3.490391
# 5865     addicting    2.818967
# 87967       resist    2.754978
# 94667    skeptical    2.596722
# 24746         calm    2.441560
# 113138     worries    2.421260
# 96353     soothing    2.404958
# 102857    terrific    2.353731
# 55029       hooked    2.344188
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
def predict(X, y, nlp_model,ml_model):
    
    X_c = nlp_model.fit_transform(X)
    print('features: {}'.format(X_c.shape[1]))
    X_train, X_test, y_train, y_test = train_test_split(X_c, y)
    print(' train records: {}'.format(X_train.shape[0]))
    print(' test records: {}'.format(X_test.shape[0]))
    ml =ml_model.fit(X_train, y_train)
    predictions=ml.predict(X_test)
    cm=confusion_matrix(predictions,y_test)
    print(cm)
    acc=accuracy_score(predictions,y_test)
    print(acc)

# %%
from sklearn.feature_extraction.text import CountVectorizer
c = CountVectorizer(stop_words = 'english')
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
predict(X,y,c,lr)
# Out:
# features: 114969
#  train records: 394360
#  test records: 131454
# c:\users\utshi\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [[ 14941   2772]
#  [  5562 108179]]
# 0.9366013966862933

# %%
from sklearn.dummy import DummyClassifier

# %%
c= CountVectorizer()
